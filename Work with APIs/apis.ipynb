# %%
import requests
import pandas as pd
import time

# %%
# keys 
API_KEY = 'AIzaSyDDYUr3ZncN-N5tomVKmzyZZVAdVr33su0'
CHANNEL_ID = 'UCHDwqcB0dlEC-fjsvzXMAEg'

# %%
# prepare url
pageToken = ''
url_start = "https://www.googleapis.com/youtube/v3/search"

url = url_start + '?key='+API_KEY+'&channelId='+CHANNEL_ID+'&part=snippet,id&order=date&maxResults=1000'+pageToken
url
# Out:
# 'https://www.googleapis.com/youtube/v3/search?key=AIzaSyDDYUr3ZncN-N5tomVKmzyZZVAdVr33su0&channelId=UCHDwqcB0dlEC-fjsvzXMAEg&part=snippet,id&order=date&maxResults=1000'

# %%
# make API call
response = requests.get(url).json()

# %%
response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'RTc66XeiBDIhBlBz9KTALpK41qA',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'DE',
#  'pageInfo': {'totalResults': 290, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'GCidhGI4FEQAqTxA-tmx9B8z1wc',
#    'id': {'kind': 'youtube#video', 'videoId': 'HmHyxx0u1X0'},
#    'snippet': {'publishedAt': '2022-09-29T14:00:18Z',
#     'channelId': 'UCHDwqcB0dlEC-fjsvzXMAEg',
#     'title': '🌹VAN SON Taiwan *  Hạ Vy | Kiếp Đơn Nghèo',
#     'description': 'SUBSCRIBE Van Son Music, nhận được những thông tin, video mới nhất từ Trung Tâm Vân Sơn.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/HmHyxx0u1X0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/HmHyxx0u1X0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/HmHyxx0u1X0/hqdefault.jpg',
#       'width': 480,
# ...
